# %%
#1.Implement weather modeling using the quadratic solution with hard coding variables (fixed variable values give in program).
import matplotlib.pyplot as plt
import numpy as np

def quadratic_solution(a, b, c, x):
    """
    Calculate the quadratic solution for the given coefficients and x value.
    """
    y = a * x**2 + b * x + c
    return y

def plot_temperature_over_time(a, b, c, time_range):
    """
    Plot temperature over time using a quadratic function.
    """
    time = np.array(time_range)
    temperature = quadratic_solution(a, b, c, time)

    plt.plot(time, temperature)
    plt.title("Temperature Over Time")
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.grid(True)
    plt.show()

def main():
    print("Weather Modeling using Quadratic Solution")

    # Hard-coded coefficients
    a_hardcoded, b_hardcoded, c_hardcoded = 2, -0.1, 1.0
    time_range = np.linspace(0, 10, 100)  # Adjust the time range as needed

    # Plot temperature over time using the quadratic function
    plot_temperature_over_time(a_hardcoded, b_hardcoded, c_hardcoded, time_range)

if __name__ == "__main__":
    main()
# Out:
# Weather Modeling using Quadratic Solution

# %%
#2.Implement weather modeling using the quadratic solution with hard coding variables through keyboard input by user
import matplotlib.pyplot as plt
import numpy as np

def quadratic_solution(a, b, c, x):
    """Calculate the quadratic solution for the given coefficients and x value.
    """
    y = a * x**2 + b * x + c
    return y

def plot_temperature_over_time(a, b, c, time_range):
    """
    Plot temperature over time using a quadratic function.
    """
    time = np.array(time_range)
    temperature = quadratic_solution(a, b, c, time)

    plt.plot(time, temperature)
    plt.title("Temperature Over Time")
    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.grid(True)
    plt.show()

def main():
    print("Weather Modeling using Quadratic Solution")

    # Hard-coded coefficients
    #a_hardcoded, b_hardcoded, c_hardcoded = -0.1, 0.5, -8
    a_hardcoded = float(input("enter the a value:"))
    b_hardcoded = float(input("enter the b value:"))
    c_hardcoded = float(input("enter the c value:"))
    time_range = np.linspace(0, 10, 100)  # Adjust the time range as needed

    # Plot temperature over time using the quadratic function
    plot_temperature_over_time(a_hardcoded, b_hardcoded, c_hardcoded, time_range)

if __name__ == "__main__":
    main()
# Out:
# Weather Modeling using Quadratic Solution
# enter the a value:0.5
# enter the b value:-25
# enter the c value:1

# %%
#3.Implement weather modeling using the quadratic solution with hard coding variables read from a file
import matplotlib.pyplot as plt

def quadratic_weather_model(time, a, b, c):
    temperature = a * (time ** 2) + b * time + c
    return temperature

def read_coefficients_from_file(file_path):
    coefficients_list = []
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                coefficients = list(map(float, line.split()))
                if len(coefficients) == 3:
                    coefficients_list.append(coefficients)
    except FileNotFoundError:
        raise FileNotFoundError(f"File not found. Please make sure '{file_path}' exists.")
    return coefficients_list

def main():
    print("Quadratic Weather Modeling")
    print("==========================")

    file_path = 'Coefficients.txt'

    try:
        coefficients_list = read_coefficients_from_file(file_path)

        time_values = list(range(0, 15))
        plt.figure(figsize=(8, 6))

        for coefficients in coefficients_list:
            a, b, c = coefficients

            temperature_values = [quadratic_weather_model(t, a, b, c) for t in time_values]

            plt.plot(time_values, temperature_values, marker='o', linestyle='-', label=f'a={a}, b={b}, c={c}')

        plt.title('Temperature Variation Over Time')
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.grid(True)
        plt.xlim(0, 10)
        plt.legend()
        plt.show()

    except FileNotFoundError as e:
        print(e)

if __name__ == "__main__":
    main()
# Out:
# Quadratic Weather Modeling
# ==========================

# %%
#4.Implement weather modeling using the quadratic solution with hard coding variables for multiple sets of inputs
import matplotlib.pyplot as plt
import numpy as np

def quadratic_temperature_model(time,a,b,c):
  #Quadratic equation: T(t)=at^2+bt+c
  temperature=a*(time**2)+b*time+c
  return temperature

#List of coefficients sets(a,b,c)
coefficients_list={
    (-0.02,1.5,20),
    (0.01,2,30),
    (-0.04,1,25),
}
#Generate time values from 0 to 50 with step1
time_values=np.arange(0,51,1)

#Plotting the results for each set of coefficients
for i, (a,b,c) in enumerate(coefficients_list):
  temperature_values=quadratic_temperature_model(time_values,a,b,c)
  label=f'Set(i+1): a={a}, b={b}, c={c}'
  plt.plot(time_values,temperature_values,label=label)

plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Quadratic temp model with multiple sets of coefficets')
plt.legend()
plt.grid(True)
plt.show()

# %%
"""5.Implement weather modeling using the quadratic solution with combination of hard coding variables (fixed)
and user input through keyboard and specify the type of graphs with values"""
import matplotlib.pyplot as plt
import numpy as np

# Get user input for the coefficients
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))

# Generate x values
x = np.linspace(-20, 20, 600)

# Calculate y values for the first function
y1 = a*x**2 + b*x + c

# Plot the first function
plt.plot(x, y1, label=f'{a}x^2 + {b}x + {c}')

# Hard-coded coefficients for the second function
a = 2
b = 4
c = -1

# Calculate y values for the second function
y2 = a*x**2 + b*x + c

# Plot the second function
label=f'Set(i+1): a={a}, b={b}, c={c}'
plt.plot(x, y2, label=f'{a}x^2 + {b}x + {c}')

# Add title, labels, legend, and grid
plt.title('Plot of the quadratic functions')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# Enter the value of a: -2
# Enter the value of b: 1
# Enter the value of c: -1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get user input for the coefficients
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))

# Generate x values
x = np.linspace(-10, 10, 400)

# Calculate y values for the first function
y1 = a*x**2 + b*x + c

# Plot the first function
plt.plot(x, y1, label=f'user:{a}x^2 + {b}x + {c}')

# Hard-coded coefficients for the second function
a = 1
b = -3
c = 2

# Calculate y values for the second function
y2 = a*x**2 + b*x + c

# Plot the second function
plt.plot(x, y2, label=f'hard-code:{a}x^2 + {b}x + {c}')

# Add title, labels, legend, and grid
plt.title('Plot of the quadratic functions')
plt.xlabel("Time")
plt.ylabel("Temperature")
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# Enter the value of a: -2
# Enter the value of b: 1
# Enter the value of c: -1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get user input for the coefficients
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))

# Generate x values
x = np.linspace(-10, 10, 400)

# Calculate y values for the first function
y1 = a*x**2 + b*x + c

# Plot the first function
plt.plot(x, y1, label=f'user:{a}x^2 + {b}x + {c}')

# Hard-coded coefficients for the second function
a = 1
b = -3
c = 2

# Calculate y values for the second function
y2 = a*x**2 + b*x + c

# Plot the second function
plt.plot(x, y2, label=f'hard-code:{a}x^2 + {b}x + {c}')

# Add title, labels, legend, and grid
plt.title('Plot of the quadratic functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# Enter the value of a: 3
# Enter the value of b: -1
# Enter the value of c: 4
